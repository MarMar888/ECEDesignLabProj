# %% [markdown]
# <a href="https://colab.research.google.com/github/MarMar888/ECEDesignLabProj/blob/main/MainClean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd

# Read the CSV file
df = pd.read_csv('3D_Print_Jobs_1743518886.csv')

# Display the first few rows of the dataset
print("Dataset Preview:")
display(df.head())

# Display basic information about the dataset
print("\nDataset Info:")
display(df.info())

#TEST
# Out:
# Dataset Preview:
#               Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                    NaN        NaN         NaN         NaN             NaN
# 1                   Name   Subitems  Tech Staff  Job Status  Select Printer
# 2  Bensch CPU case parts        NaN         NaN         NaN             NaN
# 3                    NaN        NaN         NaN         NaN             NaN
# 4                    NaN        NaN         NaN         NaN             NaN
#
#                                           Unnamed: 5       Unnamed: 6  \
# 0                                                NaN              NaN
# 1                                Slicer Project File             Paid
# 2  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#                  Unnamed: 7      Unnamed: 8         Unnamed: 9  ...  \
# 0                       NaN             NaN                NaN  ...
# 1  Materials Fee Paid (EMU)       User Name  Printer Requested  ...
# 2           Not Checked Yet  Vincent Bensch         Bambu Labs  ...
# 3                       NaN             NaN                NaN  ...
# 4                       NaN             NaN                NaN  ...
#
#   Unnamed: 44 Unnamed: 45 Unnamed: 46        Unnamed: 47  \
# 0         NaN         NaN         NaN                NaN
# 1  Date Added  Date Added    Print ID  Job Time Tracking
# 2         NaN         NaN  8215168794                NaN
# 3         NaN         NaN         NaN           00:00:00
# 4         NaN         NaN         NaN                NaN
#
#                            Unnamed: 48   Unnamed: 49       Unnamed: 50  \
# 0                                  NaN           NaN               NaN
# 1                         Creation Log  Archive Date  Reason for Print
# 2  Deleted member Jan 10, 2025 3:00 PM           NaN               NaN
# 3                                  NaN           NaN               NaN
# 4                                  NaN           NaN               NaN
#
#        Unnamed: 51  Unnamed: 52  Unnamed: 53
# 0              NaN          NaN          NaN
# 1  Staff Assisting  Delay Count  Print Count
# 2              NaN            0            1
# 3              NaN            0            1
# 4              NaN          NaN          NaN
#
# [5 rows x 54 columns]
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1973 entries, 0 to 1972
# Data columns (total 54 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1937 non-null   object
#  1   Unnamed: 1   4 non-null      object
#  2   Unnamed: 2   975 non-null    object
#  3   Unnamed: 3   1934 non-null   object
#  4   Unnamed: 4   1934 non-null   object
#  5   Unnamed: 5   1934 non-null   object
#  6   Unnamed: 6   1935 non-null   object
#  7   Unnamed: 7   1934 non-null   object
#  8   Unnamed: 8   1935 non-null   object
#  9   Unnamed: 9   1935 non-null   object
#  10  Unnamed: 10  1935 non-null   object
#  11  Unnamed: 11  10 non-null     object
#  12  Unnamed: 12  1933 non-null   object
#  13  Unnamed: 13  1109 non-null   object
#  14  Unnamed: 14  1934 non-null   object
#  15  Unnamed: 15  78 non-null     object
#  16  Unnamed: 16  400 non-null    object
#  17  Unnamed: 17  1941 non-null   object
#  18  Unnamed: 18  4 non-null      object
#  19  Unnamed: 19  1935 non-null   object
#  20  Unnamed: 20  1932 non-null   object
#  21  Unnamed: 21  1932 non-null   object
#  22  Unnamed: 22  1932 non-null   object
#  23  Unnamed: 23  1932 non-null   object
#  24  Unnamed: 24  4 non-null      object
#  25  Unnamed: 25  260 non-null    object
#  26  Unnamed: 26  162 non-null    object
#  27  Unnamed: 27  1941 non-null   object
#  28  Unnamed: 28  1705 non-null   object
#  29  Unnamed: 29  1705 non-null   object
#  30  Unnamed: 30  1705 non-null   object
#  31  Unnamed: 31  1705 non-null   object
#  32  Unnamed: 32  1705 non-null   object
#  33  Unnamed: 33  4 non-null      object
#  34  Unnamed: 34  54 non-null     object
#  35  Unnamed: 35  54 non-null     object
#  36  Unnamed: 36  1941 non-null   object
#  37  Unnamed: 37  16 non-null     object
#  38  Unnamed: 38  16 non-null     object
#  39  Unnamed: 39  16 non-null     object
#  40  Unnamed: 40  10 non-null     object
#  41  Unnamed: 41  10 non-null     object
#  42  Unnamed: 42  1935 non-null   object
#  43  Unnamed: 43  1941 non-null   object
#  44  Unnamed: 44  4 non-null      object
#  45  Unnamed: 45  4 non-null      object
#  46  Unnamed: 46  1935 non-null   object
#  47  Unnamed: 47  10 non-null     object
#  48  Unnamed: 48  1935 non-null   object
#  49  Unnamed: 49  4 non-null      object
#  50  Unnamed: 50  4 non-null      object
#  51  Unnamed: 51  4 non-null      object
#  52  Unnamed: 52  1941 non-null   object
#  53  Unnamed: 53  1941 non-null   object
# dtypes: object(54)
# memory usage: 832.5+ KB
# None

# %%
df = df.drop(0)

# %%
df.head()
# Out:
#               Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 1                   Name   Subitems  Tech Staff  Job Status  Select Printer
# 2  Bensch CPU case parts        NaN         NaN         NaN             NaN
# 3                    NaN        NaN         NaN         NaN             NaN
# 4                    NaN        NaN         NaN         NaN             NaN
# 5                    NaN        NaN         NaN         NaN             NaN
#
#                                           Unnamed: 5       Unnamed: 6  \
# 1                                Slicer Project File             Paid
# 2  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5                                                NaN              NaN
#
#                  Unnamed: 7      Unnamed: 8         Unnamed: 9  ...  \
# 1  Materials Fee Paid (EMU)       User Name  Printer Requested  ...
# 2           Not Checked Yet  Vincent Bensch         Bambu Labs  ...
# 3                       NaN             NaN                NaN  ...
# 4                       NaN             NaN                NaN  ...
# 5                       NaN             NaN                NaN  ...
#
#   Unnamed: 44 Unnamed: 45 Unnamed: 46        Unnamed: 47  \
# 1  Date Added  Date Added    Print ID  Job Time Tracking
# 2         NaN         NaN  8215168794                NaN
# 3         NaN         NaN         NaN           00:00:00
# 4         NaN         NaN         NaN                NaN
# 5         NaN         NaN         NaN                NaN
#
#                            Unnamed: 48   Unnamed: 49       Unnamed: 50  \
# 1                         Creation Log  Archive Date  Reason for Print
# 2  Deleted member Jan 10, 2025 3:00 PM           NaN               NaN
# 3                                  NaN           NaN               NaN
# 4                                  NaN           NaN               NaN
# 5                                  NaN           NaN               NaN
#
#        Unnamed: 51  Unnamed: 52  Unnamed: 53
# 1  Staff Assisting  Delay Count  Print Count
# 2              NaN            0            1
# 3              NaN            0            1
# 4              NaN          NaN          NaN
# 5              NaN          NaN          NaN
#
# [5 rows x 54 columns]

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(1)

# %%
df.head(20)
# Out:
# 1                         Name Subitems Tech Staff  Job Status Select Printer  \
# 2        Bensch CPU case parts      NaN        NaN         NaN            NaN
# 3                          NaN      NaN        NaN         NaN            NaN
# 4                          NaN      NaN        NaN         NaN            NaN
# 5                          NaN      NaN        NaN         NaN            NaN
# 6                          NaN      NaN        NaN         NaN            NaN
# 7                 FMEP Cubes 1      NaN        NaN  To Be Paid         Komodo
# 8            AED_Drone_Parts_1      NaN        NaN  To Be Paid        Tigress
# 9            AED_Drone_Parts_2      NaN        NaN  To Be Paid   Master Shifu
# 10           Top-Down Mount v1      NaN        NaN  To Be Paid  Master Oogway
# 11                    BES Base      NaN        NaN  To Be Paid          Viper
# 12           LilahProjectTest1      NaN        NaN  To Be Paid       Tai Lung
# 13                Gel_fixtures      NaN        NaN  To Be Paid         Monkey
# 14   Bensch 2025-01-27 Plate 1      NaN        NaN  To Be Paid       Mr. Ping
# 15   Bensch 2025-27-01 Plate 2      NaN        NaN  To Be Paid       Mr. Ping
# 16              Krishiv Dhupar      NaN        NaN  To Be Paid         Mantis
# 17                  Jake Evans      NaN        NaN  To Be Paid       Tai Lung
# 18                        plow      NaN        NaN  To Be Paid   Master Shifu
# 19               PS5 joysticks      NaN        NaN  To Be Paid             Po
# 20                PS5 joystick      NaN        NaN  To Be Paid             Po
# 21  jrvollmer Short Stand Base      NaN        NaN  To Be Paid          Viper
#
# 1                                 Slicer Project File             Paid  \
# 2   https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7   https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 8   https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 9   https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 10  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 11  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 12  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 13  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 14  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 15  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 16  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 17  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 18  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 19  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 20  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
# 21  https://uw-makerspace-team.monday.com/protecte...  Pending Payment
#
# 1  Materials Fee Paid (EMU)            User Name Printer Requested  ...  \
# 2           Not Checked Yet       Vincent Bensch        Bambu Labs  ...
# 3                       NaN                  NaN               NaN  ...
# 4                       NaN                  NaN               NaN  ...
# 5                       NaN                  NaN               NaN  ...
# 6                       NaN                  NaN               NaN  ...
# 7                      PAID         Ben Davidson        Bambu Labs  ...
# 8                      PAID       Lennon Rodgers        Bambu Labs  ...
# 9                      PAID       Lennon Rodgers        Bambu Labs  ...
# 10                     PAID     Carter Sifferman        Bambu Labs  ...
# 11                     PAID      Brandon Schmall        Bambu Labs  ...
# 12                     PAID        Lilah Kirkham        Bambu Labs  ...
# 13                     PAID  Liam Sullivan-Konyn        Bambu Labs  ...
# 14                     PAID       Vincent Bensch        Bambu Labs  ...
# 15                     PAID       Vincent Bensch        Bambu Labs  ...
# 16                 NOT Paid       Krishiv Dhupar        Bambu Labs  ...
# 17                     PAID           Jake Evans        Bambu Labs  ...
# 18                     PAID           Jake Evans        Bambu Labs  ...
# 19                     PAID         Carter Henry        Bambu Labs  ...
# 20                     PAID         Carter Henry        Bambu Labs  ...
# 21                     PAID        James Vollmer        Bambu Labs  ...
#
# 1  Date Added Date Added    Print ID Job Time Tracking  \
# 2         NaN        NaN  8215168794               NaN
# 3         NaN        NaN         NaN          00:00:00
# 4         NaN        NaN         NaN               NaN
# 5         NaN        NaN         NaN               NaN
# 6         NaN        NaN         NaN               NaN
# 7         NaN        NaN  8171785086               NaN
# 8         NaN        NaN  8214378089               NaN
# 9         NaN        NaN  8214392486               NaN
# 10        NaN        NaN  8238119583               NaN
# 11        NaN        NaN  8269757333               NaN
# 12        NaN        NaN  8321390406               NaN
# 13        NaN        NaN  8331849542               NaN
# 14        NaN        NaN  8332075134               NaN
# 15        NaN        NaN  8332118284               NaN
# 16        NaN        NaN  8332840625               NaN
# 17        NaN        NaN  8333910287               NaN
# 18        NaN        NaN  8333985541               NaN
# 19        NaN        NaN  8334391623               NaN
# 20        NaN        NaN  8334411122               NaN
# 21        NaN        NaN  8334462786               NaN
#
# 1                                        Creation Log Archive Date  \
# 2                 Deleted member Jan 10, 2025 3:00 PM          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7   Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 8   Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 9   Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 10  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 11  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 12  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 13  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 14  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 15  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 16  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 17  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 18  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 19  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 20  Design Innovation Lab Undergraduate Staff Jan ...          NaN
# 21  Design Innovation Lab Undergraduate Staff Jan ...          NaN
#
# 1  Reason for Print Staff Assisting Delay Count Print Count
# 2               NaN             NaN           0           1
# 3               NaN             NaN           0           1
# 4               NaN             NaN         NaN         NaN
# 5               NaN             NaN         NaN         NaN
# 6               NaN             NaN         NaN         NaN
# 7               NaN             NaN           0           1
# 8               NaN             NaN           0           1
# 9               NaN             NaN           0           1
# 10              NaN             NaN           0           1
# 11              NaN             NaN           0           1
# 12              NaN             NaN           0           1
# 13              NaN             NaN           0           1
# 14              NaN             NaN           0           1
# 15              NaN             NaN           0           1
# 16              NaN             NaN           0           1
# 17              NaN             NaN           0           1
# 18              NaN             NaN           0           1
# 19              NaN             NaN           0           1
# 20              NaN             NaN           0           1
# 21              NaN             NaN           0           1
#
# [20 rows x 54 columns]

# %%
df = df[df['Print ID'].notna()]

# %%
df = df.drop_duplicates(subset=['Print ID'])

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1932, 54)
