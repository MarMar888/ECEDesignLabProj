# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
# merge material quantity
# make quantatative factors

import pandas as pd

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer


df = pd.read_csv('cleaned.csv')
categorical_cols = ['User Type', 'Material 1', 'Material 2', 'Select Printer', 'Printer Requested', 'Printed On','Material_Category1', 'Sliced by']

# Convert categorical variables to numerical using Label Encoding
label_encoders = {}
value_mappings = {}

for col in categorical_cols:
    # Create a label encoder for each categorical column
    label_encoders[col] = LabelEncoder()
    
    # Fill missing values with 'missing' before encoding
    df[col] = df[col].fillna('missing')
    
    # Fit and transform the column
    df[col] = label_encoders[col].fit_transform(df[col])
    
    # Store the mapping between original values and encoded values
    value_mappings[col] = dict(zip(label_encoders[col].classes_, 
                                 label_encoders[col].transform(label_encoders[col].classes_)))

# Display the mappings for each categorical column
for col, mapping in value_mappings.items():
    print(f"\nMapping for {col}:")
    for original, encoded in mapping.items():
        print(f"{original}: {encoded}")
# Out:
# Mapping for User Type:
# Faculty / Staff: 0
# Graduate: 1
# Undergraduate: 2
#
# Mapping for Material 1:
# Bambu Labs ABS: 0
# Bambu Labs ABS-GF: 1
# Bambu Labs ASA: 2
# Bambu Labs PC: 3
# Bambu Labs PETG Basic: 4
# Bambu Labs PETG HF: 5
# Bambu Labs PETG Translucent: 6
# Bambu Labs PLA Basic: 7
# Bambu Labs PLA Matte: 8
# Bambu Labs PLA-CF: 9
# Bambu Labs TPU 95A HF: 10
# Formlabs BioMed Clear (v1): 11
# Formlabs Black (v4): 12
# Formlabs Black (v5): 13
# Formlabs Clear (v3): 14
# Formlabs Durable (v2): 15
# Formlabs Elastic 50A (v1): 16
# Formlabs Flexible 80A (v2): 17
# Formlabs High Temp (v2): 18
# Formlabs Rigid 4000 (v1): 19
# Formlabs Tough 1500 (v1): 20
# Formlabs Tough 1500 (v1.1): 21
# Formlabs White (v4): 22
# Formlabs White (v5): 23
# Fromlabs Clear (v5): 24
# Markforged Onyx: 25
# Nylon 12: 26
# Stratasys ABS M30: 27
# Stratasys PC-ABS: 28
# Ultimaker Tough PLA: 29
# missing: 30
#
# Mapping for Material 2:
# Bambu Labs ABS: 0
# Bambu Labs ASA: 1
# Bambu Labs PC: 2
# Bambu Labs PETG Basic: 3
# Bambu Labs PETG Translucent: 4
# Bambu Labs PLA Basic: 5
# Bambu Labs PLA Matte: 6
# Bambu Labs PLA-CF: 7
# Markforged Fiberglass: 8
# Stratasys ABS M30: 9
# Stratasys QSR Support: 10
# Ultimaker Tough PLA: 11
# missing: 12
#
# Mapping for Select Printer:
# Bunny: 0
# Chameleon: 1
# Crane: 2
# Croc: 3
# Form 2 - CuddlyTurtle: 4
# Form 2 - HolisticKitty: 5
# Form 2 - PoisedCoyote: 6
# Form 3 - AccurateGalah: 7
# Form 3 - DynamicFox: 8
# Form 3 - OvertWobbegong: 9
# Form 3 - PrettyVulture: 10
# Form 3 - SoftThylacine: 11
# Form 4 - ActiveBobcat: 12
# Form 4 - CuriousFalcon: 13
# Form 4 - FluffyMallard: 14
# Form 4 - GoofyGoshawk: 15
# Form 4 - SassyGoldfinch: 16
# Fuse 1: 17
# Gator: 18
# Kai: 19
# Komodo: 20
# Mantis: 21
# Markforged Onyx Pro: 22
# Master Oogway: 23
# Master Shifu: 24
# Mei Mei: 25
# Monkey: 26
# Mr. Ping: 27
# Ox: 28
# Po: 29
# Rhino: 30
# Shen: 31
# Stratasys F370 (##52): 32
# Stratasys F370 (##98): 33
# Tai Lung: 34
# Tigress: 35
# Ultimaker S3 - Tahiti: 36
# Ultimaker S5 - Chinstrap: 37
# Ultimaker S5 - Emperor: 38
# Ultimaker S5 - Galapagos: 39
# Ultimaker S5 - Gentoo: 40
# Ultimaker S5 - Humboldt: 41
# Ultimaker S5 - Little Blue: 42
# Viper: 43
#
# Mapping for Printer Requested:
# Bambu Labs: 0
# Form 2/3/4: 1
# Fuse 1: 2
# Markforged: 3
# Stratasys F370: 4
# Ultimaker: 5
#
# Mapping for Printed On:
# Bambu Labs: 0
# Form 2/3: 1
# Fuse 1: 2
# Markforged: 3
# Stratasys F370: 4
# Ultimaker: 5
# missing: 6
#
# Mapping for Material_Category1:
# ABS: 0
# Nylon: 1
# Other: 2
# PLA: 3
# Resin: 4
#
# Mapping for Sliced by:
# Makerspace Staff: 0
# User: 1
# User with Staff Assistance: 2

# %%
df.head()
# Out:
#    Row               Name  Select Printer  \
# 0    7       FMEP Cubes 1              20
# 1    8  AED_Drone_Parts_1              35
# 2    9  AED_Drone_Parts_2              24
# 3   10  Top-Down Mount v1              23
# 4   11           BES Base              43
#
#                                  Slicer Project File  Printer Requested  \
# 0  https://uw-makerspace-team.monday.com/protecte...                  0
# 1  https://uw-makerspace-team.monday.com/protecte...                  0
# 2  https://uw-makerspace-team.monday.com/protecte...                  0
# 3  https://uw-makerspace-team.monday.com/protecte...                  0
# 4  https://uw-makerspace-team.monday.com/protecte...                  0
#
#              User Email                Printer Note  Material 1 Qty  \
# 0  bmdavidson2@wisc.edu   X1E - ABS White/ASA White          420.82
# 1    lprodgers@wisc.edu   X1C - Black PLA/White PLA           55.00
# 2    lprodgers@wisc.edu     X1C - Blue PLA/Gray PLA           97.00
# 3    sifferman@wisc.edu  X1C - White PLA/Purple PLA          274.64
# 4    baschmall@wisc.edu    X1C - White ASA/Teal ASA           36.50
#
#    User Type  Material 1  ...  Material 2  Material 2 Cost/Unit.1  \
# 0          1           0  ...           1                    0.05
# 1          1           8  ...           6                    0.05
# 2          1           8  ...           6                    0.05
# 3          1           8  ...           6                    0.05
# 4          1           8  ...           6                    0.05
#
#    Printed On.1  Print Cost  Sliced by Print Time (Hours)    Print ID  \
# 0    Bambu Labs       21.04          1                 14  8171785086
# 1    Bambu Labs        2.75          0                  2  8214378089
# 2    Bambu Labs        4.85          1                  3  8214392486
# 3    Bambu Labs       13.73          1                  9  8238119583
# 4    Bambu Labs        1.83          1                  1  8269757333
#
#                                         Creation Log  Material_Category1  \
# 0  Design Innovation Lab Undergraduate Staff Jan ...                   0
# 1  Design Innovation Lab Undergraduate Staff Jan ...                   3
# 2  Design Innovation Lab Undergraduate Staff Jan ...                   3
# 3  Design Innovation Lab Undergraduate Staff Jan ...                   3
# 4  Design Innovation Lab Undergraduate Staff Jan ...                   3
#
#    Material_Category2
# 0                 ABS
# 1                 PLA
# 2                 PLA
# 3                 PLA
# 4                 PLA
#
# [5 rows x 23 columns]

# %%
df.drop(columns=['Row','Name', 'Slicer Project File', 'Printer Note', 'Material 2 Cost/Unit.1', 'Material 2 Qty', 'Material 2', 'Material 2 Cost/Unit', 'Printed On.1', 'Print Cost', 'Sliced by', 'Print ID'], inplace=True)

# %%
df.head()
# Out:
#    Select Printer  Printer Requested            User Email  Material 1 Qty  \
# 0              20                  0  bmdavidson2@wisc.edu          420.82
# 1              35                  0    lprodgers@wisc.edu           55.00
# 2              24                  0    lprodgers@wisc.edu           97.00
# 3              23                  0    sifferman@wisc.edu          274.64
# 4              43                  0    baschmall@wisc.edu           36.50
#
#    User Type  Material 1  Printed On  Print Time (Hours)  \
# 0          1           0           0                  14
# 1          1           8           0                   2
# 2          1           8           0                   3
# 3          1           8           0                   9
# 4          1           8           0                   1
#
#                                         Creation Log  Material_Category1  \
# 0  Design Innovation Lab Undergraduate Staff Jan ...                   0
# 1  Design Innovation Lab Undergraduate Staff Jan ...                   3
# 2  Design Innovation Lab Undergraduate Staff Jan ...                   3
# 3  Design Innovation Lab Undergraduate Staff Jan ...                   3
# 4  Design Innovation Lab Undergraduate Staff Jan ...                   3
#
#   Material_Category2
# 0                ABS
# 1                PLA
# 2                PLA
# 3                PLA
# 4                PLA

# %%
df.drop(columns=['User Email','Creation Log','Material_Category2'], inplace=True)

# %%
df.head()
# Out:
#    Select Printer  Printer Requested  Material 1 Qty  User Type  Material 1  \
# 0              20                  0          420.82          1           0
# 1              35                  0           55.00          1           8
# 2              24                  0           97.00          1           8
# 3              23                  0          274.64          1           8
# 4              43                  0           36.50          1           8
#
#    Printed On  Print Time (Hours)  Material_Category1
# 0           0                  14                   0
# 1           0                   2                   3
# 2           0                   3                   3
# 3           0                   9                   3
# 4           0                   1                   3

# %%
df.describe()
# Out:
#        Select Printer  Printer Requested  Material 1 Qty    User Type  \
# count     1928.000000        1928.000000     1928.000000  1928.000000
# mean        22.877593           0.247407       76.978828     1.683610
# std         10.477324           0.808937      113.151431     0.604001
# min          0.000000           0.000000        0.000000     0.000000
# 25%         18.000000           0.000000        7.972500     2.000000
# 50%         24.000000           0.000000       34.505000     2.000000
# 75%         29.000000           0.000000       97.840000     2.000000
# max         43.000000           5.000000      973.700000     2.000000
#
#         Material 1   Printed On  Print Time (Hours)  Material_Category1
# count  1928.000000  1928.000000         1928.000000         1928.000000
# mean      9.592324     0.254149            3.958506            2.630187
# std       5.732652     0.829986            5.590909            1.103216
# min       0.000000     0.000000            1.000000            0.000000
# 25%       8.000000     0.000000            1.000000            3.000000
# 50%       8.000000     0.000000            2.000000            3.000000
# 75%       8.000000     0.000000            4.000000            3.000000
# max      30.000000     6.000000           60.000000            4.000000

# %%
df.to_csv('PCA_ready.csv', index=False)

# %%
df_map = pd.DataFrame(value_mappings)

df_map.to_csv('value_mappings.csv', index=True)
